# %% [markdown]
# <h1>Содержание<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Подготовка-данных" data-toc-modified-id="Подготовка-данных-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Подготовка данных</a></span></li><li><span><a href="#Исследование-задачи" data-toc-modified-id="Исследование-задачи-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Исследование задачи</a></span><ul class="toc-item"><li><span><a href="#Случайный-лес-без-учета-дисбаланса." data-toc-modified-id="Случайный-лес-без-учета-дисбаланса.-2.1"><span class="toc-item-num">2.1&nbsp;&nbsp;</span>Случайный лес без учета дисбаланса.</a></span></li><li><span><a href="#Дерево-решений-без-учёта-дисбаланса" data-toc-modified-id="Дерево-решений-без-учёта-дисбаланса-2.2"><span class="toc-item-num">2.2&nbsp;&nbsp;</span>Дерево решений без учёта дисбаланса</a></span></li><li><span><a href="#Логистическая-регрессия-без-учёта-дисбаланса." data-toc-modified-id="Логистическая-регрессия-без-учёта-дисбаланса.-2.3"><span class="toc-item-num">2.3&nbsp;&nbsp;</span>Логистическая регрессия без учёта дисбаланса.</a></span></li><li><span><a href="#Итог" data-toc-modified-id="Итог-2.4"><span class="toc-item-num">2.4&nbsp;&nbsp;</span>Итог</a></span></li></ul></li><li><span><a href="#Борьба-с-дисбалансом" data-toc-modified-id="Борьба-с-дисбалансом-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Борьба с дисбалансом</a></span><ul class="toc-item"><li><span><a href="#Взвешивание-классов" data-toc-modified-id="Взвешивание-классов-3.1"><span class="toc-item-num">3.1&nbsp;&nbsp;</span>Взвешивание классов</a></span><ul class="toc-item"><li><span><a href="#Взвешивание-классов---Логистическая-регрессия" data-toc-modified-id="Взвешивание-классов---Логистическая-регрессия-3.1.1"><span class="toc-item-num">3.1.1&nbsp;&nbsp;</span>Взвешивание классов - Логистическая регрессия</a></span></li><li><span><a href="#Взвешивание-классов---Решающее-дерево" data-toc-modified-id="Взвешивание-классов---Решающее-дерево-3.1.2"><span class="toc-item-num">3.1.2&nbsp;&nbsp;</span>Взвешивание классов - Решающее дерево</a></span></li><li><span><a href="#Взвешивание-классов---Случайный-лес." data-toc-modified-id="Взвешивание-классов---Случайный-лес.-3.1.3"><span class="toc-item-num">3.1.3&nbsp;&nbsp;</span>Взвешивание классов - Случайный лес.</a></span></li></ul></li><li><span><a href="#Увеличение-выборки." data-toc-modified-id="Увеличение-выборки.-3.2"><span class="toc-item-num">3.2&nbsp;&nbsp;</span>Увеличение выборки.</a></span><ul class="toc-item"><li><span><a href="#Увеличение-выборки---Логистическая-регрессия." data-toc-modified-id="Увеличение-выборки---Логистическая-регрессия.-3.2.1"><span class="toc-item-num">3.2.1&nbsp;&nbsp;</span>Увеличение выборки - Логистическая регрессия.</a></span></li><li><span><a href="#Увеличение-выборки---Дерево-решений." data-toc-modified-id="Увеличение-выборки---Дерево-решений.-3.2.2"><span class="toc-item-num">3.2.2&nbsp;&nbsp;</span>Увеличение выборки - Дерево решений.</a></span></li><li><span><a href="#Увеличение-выборки---Cлучайный-лес." data-toc-modified-id="Увеличение-выборки---Cлучайный-лес.-3.2.3"><span class="toc-item-num">3.2.3&nbsp;&nbsp;</span>Увеличение выборки - Cлучайный лес.</a></span></li></ul></li><li><span><a href="#Уменьшение-выборки" data-toc-modified-id="Уменьшение-выборки-3.3"><span class="toc-item-num">3.3&nbsp;&nbsp;</span>Уменьшение выборки</a></span><ul class="toc-item"><li><span><a href="#Уменьшение-выборки---Дерево-решений." data-toc-modified-id="Уменьшение-выборки---Дерево-решений.-3.3.1"><span class="toc-item-num">3.3.1&nbsp;&nbsp;</span>Уменьшение выборки - Дерево решений.</a></span></li><li><span><a href="#Уменьшшение-выборки---Логистическая-регрессия" data-toc-modified-id="Уменьшшение-выборки---Логистическая-регрессия-3.3.2"><span class="toc-item-num">3.3.2&nbsp;&nbsp;</span>Уменьшшение выборки - Логистическая регрессия</a></span></li><li><span><a href="#Уменьшение-выборки---Случайный-лес." data-toc-modified-id="Уменьшение-выборки---Случайный-лес.-3.3.3"><span class="toc-item-num">3.3.3&nbsp;&nbsp;</span>Уменьшение выборки - Случайный лес.</a></span></li></ul></li><li><span><a href="#Изменение-порога." data-toc-modified-id="Изменение-порога.-3.4"><span class="toc-item-num">3.4&nbsp;&nbsp;</span>Изменение порога.</a></span><ul class="toc-item"><li><span><a href="#Изменение-порога---Логистическая-регрессия." data-toc-modified-id="Изменение-порога---Логистическая-регрессия.-3.4.1"><span class="toc-item-num">3.4.1&nbsp;&nbsp;</span>Изменение порога - Логистическая регрессия.</a></span></li><li><span><a href="#Изменение-порога---Решающее-дерево." data-toc-modified-id="Изменение-порога---Решающее-дерево.-3.4.2"><span class="toc-item-num">3.4.2&nbsp;&nbsp;</span>Изменение порога - Решающее дерево.</a></span></li><li><span><a href="#Изменение-порога---Случайный-лес." data-toc-modified-id="Изменение-порога---Случайный-лес.-3.4.3"><span class="toc-item-num">3.4.3&nbsp;&nbsp;</span>Изменение порога - Случайный лес.</a></span></li></ul></li><li><span><a href="#Итог" data-toc-modified-id="Итог-3.5"><span class="toc-item-num">3.5&nbsp;&nbsp;</span>Итог</a></span></li></ul></li><li><span><a href="#Тестирование-модели" data-toc-modified-id="Тестирование-модели-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Тестирование модели</a></span></li><li><span><a href="#Вывод" data-toc-modified-id="Вывод-5"><span class="toc-item-num">5&nbsp;&nbsp;</span>Вывод</a></span></li><li><span><a href="#Чек-лист-готовности-проекта" data-toc-modified-id="Чек-лист-готовности-проекта-6"><span class="toc-item-num">6&nbsp;&nbsp;</span>Чек-лист готовности проекта</a></span></li></ul></div>

# %% [markdown]
# # Отток клиентов

# %% [markdown]
# Из «Бета-Банка» стали уходить клиенты. Каждый месяц. Немного, но заметно. Банковские маркетологи посчитали: сохранять текущих клиентов дешевле, чем привлекать новых.
#
# Нужно спрогнозировать, уйдёт клиент из банка в ближайшее время или нет. Предоставлены исторические данные о поведении клиентов и расторжении договоров с банком.
#
# Нужна модель с предельно большим значением *F1*-меры. Необходимо довести метрику до 0.59.
#
# Дополнительно нужно измерить *AUC-ROC*, сравнить её значение с *F1*-мерой.
#
# Источник данных: [https://www.kaggle.com/barelydedicated/bank-customer-churn-modeling](https://www.kaggle.com/barelydedicated/bank-customer-churn-modeling)
#
# Достигать целей будем с помощью моделей случайного леса, логистической регрессии и дерева решений. В исследовании нужно учесть важный момент - дисбаланс классов.

# %%
import pandas as pd
import numpy as np

from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.tree import DecisionTreeClassifier

from sklearn.metrics import f1_score
from sklearn.model_selection import GridSearchCV
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.utils import shuffle
from sklearn.metrics import roc_auc_score
from sklearn.metrics import recall_score, precision_score
from sklearn.metrics import confusion_matrix

from sklearn.dummy import DummyClassifier

# %% [markdown]
# ## Подготовка данных

# %%
data = pd.read_csv('/datasets/Churn.csv')
data.head()
# Out:
#    RowNumber  CustomerId   Surname  CreditScore Geography  Gender  Age  \
# 0          1    15634602  Hargrave          619    France  Female   42
# 1          2    15647311      Hill          608     Spain  Female   41
# 2          3    15619304      Onio          502    France  Female   42
# 3          4    15701354      Boni          699    France  Female   39
# 4          5    15737888  Mitchell          850     Spain  Female   43
#
#    Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 0     2.0       0.00              1          1               1
# 1     1.0   83807.86              1          0               1
# 2     8.0  159660.80              3          1               0
# 3     1.0       0.00              2          0               0
# 4     2.0  125510.82              1          1               1
#
#    EstimatedSalary  Exited
# 0        101348.88       1
# 1        112542.58       0
# 2        113931.57       1
# 3         93826.63       0
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 14 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   RowNumber        10000 non-null  int64
#  1   CustomerId       10000 non-null  int64
#  2   Surname          10000 non-null  object
#  3   CreditScore      10000 non-null  int64
#  4   Geography        10000 non-null  object
#  5   Gender           10000 non-null  object
#  6   Age              10000 non-null  int64
#  7   Tenure           9091 non-null   float64
#  8   Balance          10000 non-null  float64
#  9   NumOfProducts    10000 non-null  int64
#  10  HasCrCard        10000 non-null  int64
#  11  IsActiveMember   10000 non-null  int64
#  12  EstimatedSalary  10000 non-null  float64
#  13  Exited           10000 non-null  int64
# dtypes: float64(3), int64(8), object(3)
# memory usage: 1.1+ MB

# %%
data.hist(figsize=(10, 10));

# %%
data.duplicated().sum()
# Out:
# 0

# %%
data = data.dropna(axis=0)

# %%
data = data.drop(['RowNumber', 'CustomerId', 'Surname'], axis=1)
data.reset_index(drop=True)
# Out:
#       CreditScore Geography  Gender  Age  Tenure    Balance  NumOfProducts  \
# 0             619    France  Female   42     2.0       0.00              1
# 1             608     Spain  Female   41     1.0   83807.86              1
# 2             502    France  Female   42     8.0  159660.80              3
# 3             699    France  Female   39     1.0       0.00              2
# 4             850     Spain  Female   43     2.0  125510.82              1
# ...           ...       ...     ...  ...     ...        ...            ...
# 9086          800    France  Female   29     2.0       0.00              2
# 9087          771    France    Male   39     5.0       0.00              2
# 9088          516    France    Male   35    10.0   57369.61              1
# 9089          709    France  Female   36     7.0       0.00              1
# 9090          772   Germany    Male   42     3.0   75075.31              2
#
#       HasCrCard  IsActiveMember  EstimatedSalary  Exited
# ...

# %% [markdown]
# В целом, данные представлены в нормальном виде. У всех столбцов правильные типы. Дубликатов нет, пропусков мало, меньше 10 % - к сожалению, это количественные данные, пока удалю их, пока непонимаю как будут работать с ними бибилиотеки. Также был удалён столбец с именем клиента, id и индексом в данных - считаю, что эти данные не понадобятся для обучения модели и только будут мешать.
#
# Остаётся только перевести качественные признаки в количественные методом OHE и масштабировать.

# %%
data_ohe = pd.get_dummies(data, drop_first=True)
data_ohe
# Out:
#       CreditScore  Age  Tenure    Balance  NumOfProducts  HasCrCard  \
# 0             619   42     2.0       0.00              1          1
# 1             608   41     1.0   83807.86              1          0
# 2             502   42     8.0  159660.80              3          1
# 3             699   39     1.0       0.00              2          0
# 4             850   43     2.0  125510.82              1          1
# ...           ...  ...     ...        ...            ...        ...
# 9994          800   29     2.0       0.00              2          0
# 9995          771   39     5.0       0.00              2          1
# 9996          516   35    10.0   57369.61              1          1
# 9997          709   36     7.0       0.00              1          0
# 9998          772   42     3.0   75075.31              2          1
#
#       IsActiveMember  EstimatedSalary  Exited  Geography_Germany  \
# 0                  1        101348.88       1                  0
# ...

# %% [markdown]
# Здесь же разобьём данные на выборки - тренировочную, валидационную и тестовую.

# %%
data_not_test, data_test = train_test_split(data_ohe, test_size=0.2, random_state=12345)

# %%
target = data_not_test['Exited']
features = data_not_test.drop('Exited', axis=1)

# %%
features_train, features_valid, target_train, target_valid = (train_test_split(features,
                                                                              target,
                                                                              test_size=0.25,
                                                                              random_state=12345,
                                                                              stratify=target)
)

# %%
scaler = StandardScaler()
scaler.fit(features_train)
# Out:
# StandardScaler()

# %%
features_train = (pd.DataFrame(scaler.transform(features_train),
                               index=features_train.index,
                               columns=features_train.columns)
)
features_train
# Out:
#       CreditScore       Age    Tenure   Balance  NumOfProducts  HasCrCard  \
# 127     -0.260791  1.603735 -1.703881  1.151994      -0.911971   0.653454
# 9        0.348522 -1.141018 -1.021453  0.927963      -0.911971   0.653454
# 2517    -0.601593 -0.289198 -1.021453  0.446152       0.813875   0.653454
# 4305     0.431141 -0.762431 -1.021453 -1.240967       0.813875   0.653454
# 5237    -0.994032 -1.235664  1.025832  1.162100      -0.911971   0.653454
# ...           ...       ...       ...       ...            ...        ...
# 1943     0.802925 -0.005258  0.343404  1.211220      -0.911971  -1.530331
# 5512    -0.240136 -0.194551 -1.021453  0.776287      -0.911971  -1.530331
# 2978    -0.725521 -0.383845 -1.362667  0.404171      -0.911971  -1.530331
# 878     -0.787485 -0.573138 -0.680239  0.923849      -0.911971   0.653454
# 1677     1.381257  0.089388  1.025832 -1.240967       0.813875   0.653454
#
#       IsActiveMember  EstimatedSalary  Geography_Germany  Geography_Spain  \
# ...

# %%
features_valid = (pd.DataFrame(scaler.transform(features_valid),
                               index=features_valid.index,
                               columns=features_valid.columns)
)
features_valid
# Out:
#       CreditScore       Age    Tenure   Balance  NumOfProducts  HasCrCard  \
# 3865    -0.281446  0.089388  0.343404 -1.240967       0.813875   0.653454
# 3651     0.844235  3.780607  1.708260 -0.244976      -0.911971   0.653454
# 434      0.338195 -0.573138  1.025832 -1.240967      -0.911971  -1.530331
# 4547     2.062861 -0.194551  1.367046  0.733031      -0.911971  -1.530331
# 6858    -0.766831  0.657268 -0.339024  0.972501      -0.911971   0.653454
# ...           ...       ...       ...       ...            ...        ...
# 6212     0.823580  2.171615 -1.021453 -1.240967       0.813875   0.653454
# 3104    -1.283198 -0.762431  0.002190  1.104136      -0.911971   0.653454
# 9021     0.049029  2.076968 -1.021453  1.723867       0.813875   0.653454
# 2156    -0.436356  0.278682  0.002190 -1.240967       0.813875   0.653454
# 849      0.565396 -1.330311 -1.703881  0.330806      -0.911971  -1.530331
#
#       IsActiveMember  EstimatedSalary  Geography_Germany  Geography_Spain  \
# ...

# %%
print(features_train.shape)
print(target_train.shape)
print(features_valid.shape)
print(target_valid.shape)
print(data_test.shape)
print(data_not_test.shape)
# Out:
# (5454, 11)
# (5454,)
# (1818, 11)
# (1818,)
# (1819, 12)
# (7272, 12)

# %% [markdown]
# В итоге у нас есть тестовая выборка, которую пока не разбивали. Есть признаки и целевой признак из рабочей выборки, удалённые столбцы, категории приведены к числам методом OHE, признаки масштабированы.

# %% [markdown]
# ## Исследование задачи

# %% [markdown]
# ### Случайный лес без учета дисбаланса.

# %% [markdown]
# Подобрал оптимальные диапазоны гиперпараметров. Пока дисбаланс классов не учитывается. Буду выбирать уже из них. Наблюдения, что малая глубина

# %%
# %%time

for depth in range(21, 31):
    for estimate in range(90, 111):
            model = RandomForestClassifier(random_state=12345, n_estimators=estimate, max_depth=depth)
            model.fit(features_train, target_train)
            predicted_valid = model.predict(features_valid)
            print(f1_score(target_valid, predicted_valid))
            print(model)
# Out:
# 0.5616438356164384
# RandomForestClassifier(max_depth=21, n_estimators=90, random_state=12345)
# 0.5587734241908007
# RandomForestClassifier(max_depth=21, n_estimators=91, random_state=12345)
# 0.5587734241908007
# RandomForestClassifier(max_depth=21, n_estimators=92, random_state=12345)
# 0.5587734241908007
# RandomForestClassifier(max_depth=21, n_estimators=93, random_state=12345)
# 0.5582191780821918
# RandomForestClassifier(max_depth=21, n_estimators=94, random_state=12345)
# 0.5606837606837606
# RandomForestClassifier(max_depth=21, n_estimators=95, random_state=12345)
# 0.5582191780821918
# RandomForestClassifier(max_depth=21, n_estimators=96, random_state=12345)
# 0.5631399317406144
# RandomForestClassifier(max_depth=21, n_estimators=97, random_state=12345)
# 0.5532646048109966
# RandomForestClassifier(max_depth=21, n_estimators=98, random_state=12345)
# 0.5582191780821918
# RandomForestClassifier(max_depth=21, n_estimators=99, random_state=12345)
# 0.5557461406518011
# ...

# %% [markdown]
# Лучше всего у нас здесь себя показало:
# 0.4927536231884058
# RandomForestClassifier(max_depth=16, n_estimators=27, random_state=12345)

# %% [markdown]
# После доработок
#
#
# 0.5824915824915825
# RandomForestClassifier(max_depth=26, n_estimators=91, random_state=12345)
#
# ОФФТОП: после доработок метрика почти на десятую улучшилась. Приятно.

# %% [markdown]
# ### Дерево решений без учёта дисбаланса

# %%
for depth in range(1, 16):
    model = DecisionTreeClassifier(random_state=12345, max_depth=depth, criterion='gini')
    model.fit(features_train, target_train)
    predicted_valid = model.predict(features_valid)
    print(f1_score(target_valid, predicted_valid))
    print(model)
# Out:
# 0.0
# DecisionTreeClassifier(max_depth=1, random_state=12345)
# 0.49765258215962443
# DecisionTreeClassifier(max_depth=2, random_state=12345)
# 0.41547861507128314
# DecisionTreeClassifier(max_depth=3, random_state=12345)
# 0.4314516129032258
# DecisionTreeClassifier(max_depth=4, random_state=12345)
# 0.5880503144654088
# DecisionTreeClassifier(max_depth=5, random_state=12345)
# 0.5054151624548737
# DecisionTreeClassifier(max_depth=6, random_state=12345)
# 0.5672609400324149
# DecisionTreeClassifier(max_depth=7, random_state=12345)
# 0.5546492659053834
# DecisionTreeClassifier(max_depth=8, random_state=12345)
# 0.5402985074626866
# DecisionTreeClassifier(max_depth=9, random_state=12345)
# 0.5333333333333333
# DecisionTreeClassifier(max_depth=10, random_state=12345)
# 0.5195936139332366
# DecisionTreeClassifier(max_depth=11, random_state=12345)
# 0.5078014184397163
# DecisionTreeClassifier(max_depth=12, random_state=12345)
# 0.47605633802816905
# ...

# %% [markdown]
# Дерево решений - лучшая модель:
#
# 0.4692737430167597
# DecisionTreeClassifier(max_depth=9, random_state=12345)

# %% [markdown]
# 0.5880503144654088
# DecisionTreeClassifier(max_depth=5, random_state=12345)
#
# Метрика улучшилась, радует. Здесь больше чем на десятую.

# %% [markdown]
# ###  Логистическая регрессия без учёта дисбаланса.

# %%
model = LogisticRegression(random_state=12345)
model.fit(features_train, target_train)
predicted_valid = model.predict(features_valid)
print(f1_score(target_valid, predicted_valid))
print(model)
# Out:
# 0.2769857433808554
# LogisticRegression(random_state=12345)

# %% [markdown]
# Здесь метрика ухудшилась с 0.33 до 0.27

# %% [markdown]
# Первую модель выбрал наобум. Затем воспользовался автоматизированным подбором гиперпараметров.

# %%
# %%time


parametrs_log_regress = {'solver': ['lbfg', 'liblinear', 'newton-c', 'newton-cholesky', 'sag', 'saga'],
                         'max_iter': range(90, 111),
                         'C': np.arange(0.2, 1.1, 0.2)
                 }
clf_log_res = LogisticRegression(random_state=12345)
grid_log_res = GridSearchCV(clf_log_res, parametrs_log_regress, cv=3)

grid_log_res.fit(features_train, target_train)
# Out:
# /opt/conda/lib/python3.9/site-packages/sklearn/model_selection/_validation.py:610: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.9/site-packages/sklearn/model_selection/_validation.py", line 593, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/opt/conda/lib/python3.9/site-packages/sklearn/linear_model/_logistic.py", line 1306, in fit
#     solver = _check_solver(self.solver, self.penalty, self.dual)
#   File "/opt/conda/lib/python3.9/site-packages/sklearn/linear_model/_logistic.py", line 434, in _check_solver
#     raise ValueError("Logistic Regression supports only solvers in %s, got"
# ValueError: Logistic Regression supports only solvers in ['liblinear', 'newton-cg', 'lbfgs', 'sag', 'saga'], got lbfg.
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# ...

# %%
grid_log_res.best_params_
# Out:
# {'C': 0.2, 'max_iter': 90, 'solver': 'sag'}

# %%
model = LogisticRegression(random_state=12345, solver='liblinear', C=0.4, max_iter=90)
model.fit(features_train, target_train)
predicted_valid = model.predict(features_valid)
print(f1_score(target_valid, predicted_valid))
print(model)
# Out:
# 0.2769857433808554
# LogisticRegression(C=0.4, max_iter=90, random_state=12345, solver='liblinear')

# %% [markdown]
# Метрика не улучшилась.

# %% [markdown]
# ### Итог

# %% [markdown]
# Лучше всего себя показал случайный лес, чуть хуже дерево решений. И ни одна из моделей не подошла к нужному показателю 0.59

# %% [markdown]
# Новый итог.
#
# Слуйчаный лес и дерево решений демонстрируют почти нужную F1 в 0.59. И это без работы с дисбалансом.
# Логистическая регрессия показывает очень плохой результат в 0.27

# %% [markdown]
# ## Борьба с дисбалансом

# %% [markdown]
# ### Взвешивание классов

# %% [markdown]
# #### Взвешивание классов - Логистическая регрессия

# %%
model = LogisticRegression(random_state=12345, class_weight='balanced')
model.fit(features_train, target_train)
predicted_valid = model.predict(features_valid)
print(f1_score(target_valid, predicted_valid))
print(model)
# Out:
# 0.47656249999999994
# LogisticRegression(class_weight='balanced', random_state=12345)

# %% [markdown]
# Видно, что метрика выросла c 0.27 до 0.47

# %% [markdown]
# #### Взвешивание классов - Решающее дерево

# %%
for depth in range(1, 16):
    model = DecisionTreeClassifier(random_state=12345, max_depth=depth, criterion='entropy', class_weight='balanced')
    model.fit(features_train, target_train)
    predicted_valid = model.predict(features_valid)
    print(f1_score(target_valid, predicted_valid))
    print(model)
# Out:
# 0.4654788418708241
# DecisionTreeClassifier(class_weight='balanced', criterion='entropy',
#                        max_depth=1, random_state=12345)
# 0.5032119914346896
# DecisionTreeClassifier(class_weight='balanced', criterion='entropy',
#                        max_depth=2, random_state=12345)
# 0.5226244343891403
# DecisionTreeClassifier(class_weight='balanced', criterion='entropy',
#                        max_depth=3, random_state=12345)
# 0.5207413945278023
# DecisionTreeClassifier(class_weight='balanced', criterion='entropy',
#                        max_depth=4, random_state=12345)
# 0.6209573091849935
# DecisionTreeClassifier(class_weight='balanced', criterion='entropy',
#                        max_depth=5, random_state=12345)
# 0.5849056603773585
# DecisionTreeClassifier(class_weight='balanced', criterion='entropy',
#                        max_depth=6, random_state=12345)
# 0.575257731958763
# DecisionTreeClassifier(class_weight='balanced', criterion='entropy',
# ...

# %% [markdown]
# Сначало было неожиданно - потому что после балансировки метрика оказалась незначительно, но хуже. 0.57
# Вручную изменил критерий и метрика улучшилась с 0.58 до 0.62
#
# 0.6209573091849935
# DecisionTreeClassifier(class_weight='balanced', criterion='entropy',
#                        max_depth=5, random_state=12345)

# %% [markdown]
# #### Взвешивание классов - Случайный лес.

# %%
# %%time

for depth in range(5, 16):
    for estimate in range(50, 101):
            model = RandomForestClassifier(random_state=12345, n_estimators=estimate, max_depth=depth, class_weight='balanced')
            model.fit(features_train, target_train)
            predicted_valid = model.predict(features_valid)
            print(f1_score(target_valid, predicted_valid))
            print(model)
# Out:
# 0.593258426966292
# RandomForestClassifier(class_weight='balanced', max_depth=5, n_estimators=50,
#                        random_state=12345)
# 0.5941704035874439
# RandomForestClassifier(class_weight='balanced', max_depth=5, n_estimators=51,
#                        random_state=12345)
# 0.5916760404949382
# RandomForestClassifier(class_weight='balanced', max_depth=5, n_estimators=52,
#                        random_state=12345)
# 0.593258426966292
# RandomForestClassifier(class_weight='balanced', max_depth=5, n_estimators=53,
#                        random_state=12345)
# 0.5900900900900901
# RandomForestClassifier(class_weight='balanced', max_depth=5, n_estimators=54,
#                        random_state=12345)
# 0.5979843225083986
# RandomForestClassifier(class_weight='balanced', max_depth=5, n_estimators=55,
#                        random_state=12345)
# 0.5966480446927375
# RandomForestClassifier(class_weight='balanced', max_depth=5, n_estimators=56,
# ...

# %% [markdown]
# Метрика снова возросла с 0.58 до 0.6268
#
# 0.6337209302325583
# RandomForestClassifier(class_weight='balanced', max_depth=11, n_estimators=83

# %% [markdown]
# ### Увеличение выборки.

# %% [markdown]
# Создадим функцию, как в тренажёре. Посмотрим какой дисбаланс классов. Забегу вперёд - увеличу в 4 раза положительный класс, потому что соотношение 4 к 1.

# %%
def upsample(features, target, repeat):
    features_zeros = features[target == 0]
    features_ones = features[target == 1]
    target_zeros = target[target == 0]
    target_ones = target[target == 1]

    features_upsampled = pd.concat([features_zeros] + [features_ones] * repeat)
    target_upsampled = pd.concat([target_zeros] + [target_ones] * repeat)
    
    features_upsampled, target_upsampled = shuffle(features_upsampled, target_upsampled, random_state=12345)
    
    return features_upsampled, target_upsampled

# %%
target.value_counts(normalize=True)
# Out:
# 0    0.795792
# 1    0.204208
# Name: Exited, dtype: float64

# %%
features_upsampled, target_upsampled = upsample(features_train, target_train, 4)

# %% [markdown]
# #### Увеличение выборки - Логистическая регрессия.

# %%
model = LogisticRegression(random_state=12345)
model.fit(features_upsampled, target_upsampled)
predicted_valid = model.predict(features_valid)
print(f1_score(target_valid, predicted_valid))
print(model)
# Out:
# 0.4774688398849473
# LogisticRegression(random_state=12345)

# %% [markdown]
# Пока образец стабильности - метрика такая же как и при взвешивании классов.

# %% [markdown]
# #### Увеличение выборки - Дерево решений.

# %%
for depth in range(1, 16):
    model = DecisionTreeClassifier(random_state=12345, max_depth=depth, criterion='entropy')
    model.fit(features_upsampled, target_upsampled)
    predicted_valid = model.predict(features_valid)
    print(f1_score(target_valid, predicted_valid))
    print(model)
# Out:
# 0.4654788418708241
# DecisionTreeClassifier(criterion='entropy', max_depth=1, random_state=12345)
# 0.5032119914346896
# DecisionTreeClassifier(criterion='entropy', max_depth=2, random_state=12345)
# 0.5226244343891403
# DecisionTreeClassifier(criterion='entropy', max_depth=3, random_state=12345)
# 0.5207413945278023
# DecisionTreeClassifier(criterion='entropy', max_depth=4, random_state=12345)
# 0.6209573091849935
# DecisionTreeClassifier(criterion='entropy', max_depth=5, random_state=12345)
# 0.5849056603773585
# DecisionTreeClassifier(criterion='entropy', max_depth=6, random_state=12345)
# 0.575257731958763
# DecisionTreeClassifier(criterion='entropy', max_depth=7, random_state=12345)
# 0.5595238095238095
# DecisionTreeClassifier(criterion='entropy', max_depth=8, random_state=12345)
# 0.5535900104058272
# DecisionTreeClassifier(criterion='entropy', max_depth=9, random_state=12345)
# 0.53099173553719
# DecisionTreeClassifier(criterion='entropy', max_depth=10, random_state=12345)
# ...

# %% [markdown]
# Метрика опять показывает результат ниже даже того, что без учета дисбаланса. Поменял критерий вручную.
# Снова
#
# 0.6209573091849935
# DecisionTreeClassifier(criterion='entropy', max_depth=5, random_state=12345)
#
# Как и при взвешивании.

# %% [markdown]
# #### Увеличение выборки - Cлучайный лес.

# %%
# %%time

for depth in range(5, 16):
    for estimate in range(50, 101):
            model = RandomForestClassifier(random_state=12345, n_estimators=estimate, max_depth=depth)
            model.fit(features_upsampled, target_upsampled)
            predicted_valid = model.predict(features_valid)
            print(f1_score(target_valid, predicted_valid))
            print(model)
# Out:
# 0.5943502824858757
# RandomForestClassifier(max_depth=5, n_estimators=50, random_state=12345)
# 0.5966101694915255
# RandomForestClassifier(max_depth=5, n_estimators=51, random_state=12345)
# 0.595505617977528
# RandomForestClassifier(max_depth=5, n_estimators=52, random_state=12345)
# 0.5970819304152638
# RandomForestClassifier(max_depth=5, n_estimators=53, random_state=12345)
# 0.5957446808510638
# RandomForestClassifier(max_depth=5, n_estimators=54, random_state=12345)
# 0.5946547884187082
# RandomForestClassifier(max_depth=5, n_estimators=55, random_state=12345)
# 0.5942350332594235
# RandomForestClassifier(max_depth=5, n_estimators=56, random_state=12345)
# 0.593576965669989
# RandomForestClassifier(max_depth=5, n_estimators=57, random_state=12345)
# 0.5909592061742006
# RandomForestClassifier(max_depth=5, n_estimators=58, random_state=12345)
# 0.5922651933701658
# RandomForestClassifier(max_depth=5, n_estimators=59, random_state=12345)
# 0.5933333333333333
# ...

# %% [markdown]
# На одну сотую хуже себя показывает, чем при взвешивании классов.
#
# 0.6285046728971962
# RandomForestClassifier(max_depth=7, n_estimators=24, random_state=12345)

# %% [markdown]
# ### Уменьшение выборки

# %% [markdown]
# Выборку уменьшил как в тренажере, взял только 0.1 от неё. Причин для изменения в ту или иную сторону не вижу.

# %%
def downsample(features, target, fraction):
    features_zeros = features[target == 0]
    features_ones = features[target == 1]
    target_zeros = target[target == 0]
    target_ones = target[target == 1]

    features_downsampled = pd.concat([features_zeros.sample(frac=fraction, random_state=12345)] + [features_ones])
    target_downsampled = pd.concat([target_zeros.sample(frac=fraction, random_state=12345)] + [target_ones])
    
    features_downsampled, target_downsampled = shuffle(features_downsampled, target_downsampled, random_state=12345)
    
    return features_downsampled, target_downsampled

features_downsampled, target_downsampled = downsample(features_train, target_train, 0.25)

# %% [markdown]
# #### Уменьшение выборки - Дерево решений.

# %%
for depth in range(1, 16):
    model = DecisionTreeClassifier(random_state=12345, max_depth=depth, criterion='gini')
    model.fit(features_downsampled, target_downsampled)
    predicted_valid = model.predict(features_valid)
    print(f1_score(target_valid, predicted_valid))
    print(model)
# Out:
# 0.4764890282131662
# DecisionTreeClassifier(max_depth=1, random_state=12345)
# 0.5080971659919028
# DecisionTreeClassifier(max_depth=2, random_state=12345)
# 0.5256410256410257
# DecisionTreeClassifier(max_depth=3, random_state=12345)
# 0.5234159779614325
# DecisionTreeClassifier(max_depth=4, random_state=12345)
# 0.5779543197616684
# DecisionTreeClassifier(max_depth=5, random_state=12345)
# 0.5702393340270552
# DecisionTreeClassifier(max_depth=6, random_state=12345)
# 0.5642633228840126
# DecisionTreeClassifier(max_depth=7, random_state=12345)
# 0.5534838076545633
# DecisionTreeClassifier(max_depth=8, random_state=12345)
# 0.5201970443349753
# DecisionTreeClassifier(max_depth=9, random_state=12345)
# 0.5278884462151394
# DecisionTreeClassifier(max_depth=10, random_state=12345)
# 0.5129740518962076
# DecisionTreeClassifier(max_depth=11, random_state=12345)
# 0.4885057471264368
# DecisionTreeClassifier(max_depth=12, random_state=12345)
# 0.49014084507042255
# ...

# %% [markdown]
# Метрика чуть хуже, чем у модели без работы с дисбалансом.
#
# 0.5779543197616684
# DecisionTreeClassifier(max_depth=5, random_state=12345)

# %% [markdown]
# #### Уменьшшение выборки - Логистическая регрессия

# %%
model = LogisticRegression(random_state=12345)
model.fit(features_downsampled, target_downsampled)
predicted_valid = model.predict(features_valid)
print(f1_score(target_valid, predicted_valid))
print(model)
# Out:
# 0.47801147227533464
# LogisticRegression(random_state=12345)

# %% [markdown]
# Можно сказать, что ничего не изменилось.

# %% [markdown]
# #### Уменьшение выборки - Случайный лес.

# %%
# %%time

for depth in range(5, 16):
    for estimate in range(50, 101):
            model = RandomForestClassifier(random_state=12345, n_estimators=estimate, max_depth=depth)
            model.fit(features_downsampled, target_downsampled)
            predicted_valid = model.predict(features_valid)
            print(f1_score(target_valid, predicted_valid))
            print(model)
# Out:
# 0.599128540305011
# RandomForestClassifier(max_depth=5, n_estimators=50, random_state=12345)
# 0.5912087912087911
# RandomForestClassifier(max_depth=5, n_estimators=51, random_state=12345)
# 0.5936473165388828
# RandomForestClassifier(max_depth=5, n_estimators=52, random_state=12345)
# 0.5934065934065933
# RandomForestClassifier(max_depth=5, n_estimators=53, random_state=12345)
# 0.5866957470010906
# RandomForestClassifier(max_depth=5, n_estimators=54, random_state=12345)
# 0.585792349726776
# RandomForestClassifier(max_depth=5, n_estimators=55, random_state=12345)
# 0.5890109890109891
# RandomForestClassifier(max_depth=5, n_estimators=56, random_state=12345)
# 0.5901639344262296
# RandomForestClassifier(max_depth=5, n_estimators=57, random_state=12345)
# 0.5923497267759562
# RandomForestClassifier(max_depth=5, n_estimators=58, random_state=12345)
# 0.5908096280087527
# RandomForestClassifier(max_depth=5, n_estimators=59, random_state=12345)
# 0.5945355191256831
# ...

# %% [markdown]
# Чуть хуже, чем при увеличении выборки.
#
# 0.6180631120783462
# RandomForestClassifier(max_depth=7, n_estimators=56, random_state=12345)

# %% [markdown]
# ### Изменение порога.

# %% [markdown]
# #### Изменение порога - Логистическая регрессия.

# %%
model = LogisticRegression(random_state=12345)
model.fit(features_train, target_train)
predicted_valid = model.predict(features_valid)


probabilities_valid = model.predict_proba(features_valid)
probabilities_one_valid = probabilities_valid[:, 1]

for threshold in np.arange(0, 0.3, 0.02):
    predicted_valid = probabilities_one_valid > threshold
    
    print('F1', f1_score(target_valid, predicted_valid))
    print('Порог', threshold)
    print(roc_auc_score(target_valid, probabilities_one_valid))
# Out:
# F1 0.33896756509821835
# Порог 0.0
# 0.7485680010878535
# F1 0.33943275388838057
# Порог 0.02
# 0.7485680010878535
# F1 0.35452793834296725
# Порог 0.04
# 0.7485680010878535
# F1 0.37344398340248963
# Порог 0.06
# 0.7485680010878535
# F1 0.39186900056465274
# Порог 0.08
# 0.7485680010878535
# F1 0.40866873065015474
# Порог 0.1
# 0.7485680010878535
# F1 0.41904761904761906
# Порог 0.12
# 0.7485680010878535
# F1 0.4454342984409799
# Порог 0.14
# 0.7485680010878535
# F1 0.45682001614205003
# Порог 0.16
# 0.7485680010878535
# F1 0.46915725456125107
# Порог 0.18
# 0.7485680010878535
# F1 0.4768211920529801
# Порог 0.2
# 0.7485680010878535
# F1 0.4742268041237113
# Порог 0.22
# 0.7485680010878535
# F1 0.4692737430167597
# Порог 0.24
# 0.7485680010878535
# F1 0.4645006016847172
# Порог 0.26
# 0.7485680010878535
# F1 0.46786632390745503
# Порог 0.28
# 0.7485680010878535

# %% [markdown]
# Максимум всё тот же 0.47

# %% [markdown]
# AUC-ROC достаточно высокая, без изменений. Посомтрим дальше.

# %% [markdown]
# #### Изменение порога - Решающее дерево.

# %%
for depth in range(1, 16):
    model = DecisionTreeClassifier(random_state=12345, max_depth=depth, criterion='gini')
    model.fit(features_train, target_train)
    predicted_valid = model.predict(features_valid)
    probabilities_valid = model.predict_proba(features_valid)
    probabilities_one_valid = probabilities_valid[:, 1]
    for threshold in np.arange(0, 0.3, 0.02):
        predicted_valid = probabilities_one_valid > threshold
        print('F1', f1_score(target_valid, predicted_valid))
        print('Порог', threshold)
        print('ROC', roc_auc_score(target_valid, probabilities_one_valid))
        print(model)
# Out:
# F1 0.33896756509821835
# Порог 0.0
# ROC 0.671788643480237
# DecisionTreeClassifier(max_depth=1, random_state=12345)
# F1 0.33896756509821835
# Порог 0.02
# ROC 0.671788643480237
# DecisionTreeClassifier(max_depth=1, random_state=12345)
# F1 0.33896756509821835
# Порог 0.04
# ROC 0.671788643480237
# DecisionTreeClassifier(max_depth=1, random_state=12345)
# F1 0.33896756509821835
# Порог 0.06
# ROC 0.671788643480237
# DecisionTreeClassifier(max_depth=1, random_state=12345)
# F1 0.33896756509821835
# Порог 0.08
# ROC 0.671788643480237
# DecisionTreeClassifier(max_depth=1, random_state=12345)
# F1 0.33896756509821835
# Порог 0.1
# ROC 0.671788643480237
# DecisionTreeClassifier(max_depth=1, random_state=12345)
# F1 0.4654788418708241
# Порог 0.12
# ROC 0.671788643480237
# DecisionTreeClassifier(max_depth=1, random_state=12345)
# F1 0.4654788418708241
# Порог 0.14
# ROC 0.671788643480237
# DecisionTreeClassifier(max_depth=1, random_state=12345)
# F1 0.4654788418708241
# Порог 0.16
# ...

# %% [markdown]
# Метрики хорошие, но ниже чем у взвешивании классов и увеличении выборки. И AUC-ROC хороший. Выше чем у логистической регрессии.
#
# F1 0.6029850746268658
# Порог 0.26
# ROC 0.823526508046204
# DecisionTreeClassifier(max_depth=5, random_state=12345)
#
# F1 0.5966183574879227
# Порог 0.24
# ROC 0.8367903106529542
# DecisionTreeClassifier(max_depth=6, random_state=12345)

# %% [markdown]
# #### Изменение порога - Случайный лес.

# %%
# %%time

for depth in range(5, 16):
    for estimate in range(50, 101):
            model = RandomForestClassifier(random_state=12345, n_estimators=estimate, max_depth=depth)
            model.fit(features_train, target_train)
            predicted_valid = model.predict(features_valid)
            probabilities_valid = model.predict_proba(features_valid)
            probabilities_one_valid = probabilities_valid[:, 1]
            for threshold in np.arange(0, 0.3, 0.02):
                predicted_valid = probabilities_one_valid > threshold
                print('F1', f1_score(target_valid, predicted_valid))
                print('Порог', threshold)
                print('ROC', roc_auc_score(target_valid, probabilities_one_valid))
                print(model)
# Out:
# F1 0.33896756509821835
# Порог 0.0
# ROC 0.8515312841700553
# RandomForestClassifier(max_depth=5, n_estimators=50, random_state=12345)
# F1 0.33896756509821835
# Порог 0.02
# ROC 0.8515312841700553
# RandomForestClassifier(max_depth=5, n_estimators=50, random_state=12345)
# F1 0.33896756509821835
# Порог 0.04
# ROC 0.8515312841700553
# RandomForestClassifier(max_depth=5, n_estimators=50, random_state=12345)
# F1 0.356388088376561
# Порог 0.06
# ROC 0.8515312841700553
# RandomForestClassifier(max_depth=5, n_estimators=50, random_state=12345)
# F1 0.3880440482433141
# Порог 0.08
# ROC 0.8515312841700553
# RandomForestClassifier(max_depth=5, n_estimators=50, random_state=12345)
# F1 0.41518113858539396
# Порог 0.1
# ROC 0.8515312841700553
# RandomForestClassifier(max_depth=5, n_estimators=50, random_state=12345)
# F1 0.44430379746835447
# Порог 0.12
# ROC 0.8515312841700553
# RandomForestClassifier(max_depth=5, n_estimators=50, random_state=12345)
# F1 0.4827586206896551
# Порог 0.14
# ...

# %% [markdown]
# Хороший показатели, но не самые высокие F1. AUC-ROC достаточно близко к 1 и самое высокое среди моделей.
#
# F1 0.6274509803921569
# Порог 0.28
# ROC 0.8643387098877313
# RandomForestClassifier(max_depth=8, n_estimators=73, random_state=12345)

# %% [markdown]
# ### Итог

# %% [markdown]
# Лучше всего себя показала модель - случайный лес при работе с дисбалансом взвешиванием классов. Хуже всего себя показала модель логистической регрессии.

# %% [markdown]
# ## Тестирование модели

# %% [markdown]
# Так как взвешивание классов не требует дополнительных усилий в виде кода и изменении данных, а также пусть и незначительно, но лучше метрика F1, то остановлюсь на случайном лесе с взвешиванием классов.
#
# RandomForestClassifier(class_weight='balanced', max_depth=11, n_estimators=83)

# %%
target_test = data_test['Exited']
features_test = data_test.drop('Exited', axis=1)

features_test = pd.DataFrame(scaler.transform(features_test), index=features_test.index, columns=features_test.columns)
features_test.head()
# Out:
#       CreditScore       Age    Tenure   Balance  NumOfProducts  HasCrCard  \
# 862      0.771943  0.184035  0.684618  0.595645      -0.911971   0.653454
# 9727    -1.241889  0.562622 -1.362667 -1.240967      -0.911971  -1.530331
# 1717     0.586051 -0.383845 -0.680239 -0.327747      -0.911971   0.653454
# 8640     0.823580 -0.667785  1.367046  0.816100      -0.911971  -1.530331
# 5288    -0.704867 -0.857078 -1.021453 -1.240967       0.813875   0.653454
#
#       IsActiveMember  EstimatedSalary  Geography_Germany  Geography_Spain  \
# 862         0.969657         0.271372          -0.578903        -0.572975
# 9727        0.969657         1.538259          -0.578903        -0.572975
# 1717       -1.031292        -1.419592          -0.578903         1.745278
# 8640       -1.031292        -0.684429          -0.578903        -0.572975
# 5288        0.969657         0.533893          -0.578903        -0.572975
#
#       Gender_Male
# 862      0.913178
# 9727    -1.095077
# ...

# %%
model = RandomForestClassifier(class_weight='balanced', max_depth=11, n_estimators=83, random_state=12345)
model.fit(features_train, target_train)

predicted_test = model.predict(features_test)
f1_score(target_test, predicted_test)
# Out:
# 0.6070381231671554

# %%
target_test = data_test['Exited']
features_test = data_test.drop('Exited', axis=1)
scaler.fit(features_test)
features_test = pd.DataFrame(scaler.transform(features_test), index=features_test.index, columns=features_test.columns)

model = RandomForestClassifier(class_weight='balanced', max_depth=11, n_estimators=83, random_state=12345)
model.fit(features_train, target_train)

predicted_test = model.predict(features_test)
print(f1_score(target_test, predicted_test))
print(confusion_matrix(target_test, predicted_test))
# Out:
# 0.6000000000000001
# [[1343  107]
#  [ 165  204]]

# %% [markdown]
# Непонимаю почему, но scaler обученный на train не хочут трансформировать test, хотя с valid всё проходит нормально. Пришлось обучать на test, чтобы нормально трансформировалось.

# %%
features_test.head()
# Out:
#       CreditScore       Age   Tenure   Balance  NumOfProducts  HasCrCard  \
# 862      0.726530  0.211264  0.70703  0.622801      -0.925442   0.624188
# 9727    -1.326070  0.592597 -1.40131 -1.197829      -0.925442  -1.602082
# 1717     0.537060 -0.360736 -0.69853 -0.292555      -0.925442   0.624188
# 8640     0.779161 -0.646737  1.40981  0.841339      -0.925442  -1.602082
# 5288    -0.778710 -0.837403 -1.04992 -1.197829       0.817186   0.624188
#
#       IsActiveMember  EstimatedSalary  Geography_Germany  Geography_Spain  \
# 862         0.953262         0.317659          -0.593647        -0.575023
# 9727        0.953262         1.615145          -0.593647        -0.575023
# 1717       -1.049029        -1.414148          -0.593647         1.739062
# 8640       -1.049029        -0.661228          -0.593647        -0.575023
# 5288        0.953262         0.586520          -0.593647        -0.575023
#
#       Gender_Male
# 862      0.900973
# 9727    -1.109911
# 1717    -1.109911
# ...

# %%
dummy_test = DummyClassifier(strategy='stratified')
dummy_test.fit(features_train, target_train)
dummy_predict = dummy_test.predict(features_test)
f1_score(target_test, dummy_predict)
# Out:
# 0.1840324763193505

# %% [markdown]
# Проверка пройдена.

# %% [markdown]
# ## Вывод

# %% [markdown]
# В рамках проекта по построению модели для прогнозирования оттока клиентов бакна были исследованы 3 модели - случайный лес, решающее дерево, логистическая регрессия.
#
# В целом данные были предоставлены в нормальном виде, с правильными типами столбцов, без дубликатов, с малым количеством пропусков, которые были удалены. К данным применялись методы OHE и масштабирования признаков. Также они были разбиты на 3 выборки в соотношении 3:1:1.
#
# Важным нюансом в проекте был дисбаланс классов.
#
# Требуемая метрика F1 должна была достигать 0.59.
#
# Логистическая регрессия показала низкий результат 0.27 и 0.47. В рамках её изучения в том числе применялся автоматический подбор гиперпараметров. Больше о ней упоминания не будет.
#
# Случайный лес и решающее дерево, наоборот практически сразу показали результат F1 0.58
#
# Далее были примененны 4 метода борьбы с дисбалансом - взвешивание классов, увеличение выборки, уменьшение выборки и изменение величины порога. По итогу лучше всего себя показала модель случайного леса с взвешиванием классов F1 = 0.63. Её было решено и протестировать.
#
# На тесте модель показала 0.60, что удоволетворяет исследованию. Также была проведена проверка на адекватность тупым классификатором со стратегией stratified - F1 = 0.2 - модель также прошла проверку на адекватность.
#
# Стоит сказать о метрике AUC-ROC , на случайном лесе достигает 0.86, с учётом изменения порогов, не менялась/менялась не сильно.
